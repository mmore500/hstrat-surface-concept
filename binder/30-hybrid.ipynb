# %%
import copy
import functools
import itertools as it
import logging
import os
import random
import sys
import typing

from hstrat import _auxiliary_lib as hstrat_aux
import interval_search as inch
from IPython.core.display import display, HTML
from matplotlib import pyplot as plt
import matplotlib as mpl
from nbmetalog import nbmetalog as nbm
import numpy as np
import opytional as opyt
import pandas as pd
import pytest
from scipy import stats as scipy_stats
import seaborn as sns
from tqdm import tqdm

from hsurf.hsurf import hybrid_algo as hybrid_algo
import pylib

random.seed(1)

logging.basicConfig(
    format="[%(funcName)s:%(lineno)d] %(message)s",
)
logger = logging.getLogger()

pylib.jupyter_hide_toggle(hide=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/hstrat/_auxiliary_lib/_check_testing_requirements.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /usr/local/lib/python3.10/dist-packages/pandera/__init__.py:40: UserWarning: Pandas and numpy have been removed from the base pandera
# dependencies. Please install pandas as part of your environment's
# dependencies or install the pandas extra with:
#
# ```bash
# pip install pandas pandera
#
# # or
# pip install 'pandera[pandas]'
# ```
#
#   warnings.warn(_warning_msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/alifedata_phyloinformatics_convert/_impl/phytrack_Systematcs.py:7: UserWarning: ImportWarning: phylotrackpy.Systematics import failed; inserting a no-op mock for Systematics. This is likely because phylotrackpy is not installed.
#   warnings.warn(

# %%
nbm.print_metadata()

pylib.jupyter_hide_toggle(hide=True)
# Out:
# context: ci
# hostname: runnervmez679
# interpreter: 3.10.12 (main, Jan  8 2026, 06:52:19) [GCC 11.4.0]
# nbcellexec: null
# nbname: 30-hybrid
# nbpath: /home/runner/work/hstrat-surface-concept/hstrat-surface-concept/binder/30-hybrid.ipynb
# revision: null
# session: 0d6521e6-22e4-40ad-8cf4-59163ff76e30
# timestamp: 2026-02-08T00:36:00Z00:00
#
#
# IPython==7.31.1
# keyname==0.6.0
# yaml==6.0.2
# hstrat==1.11.1
# hsurf==1.0.2
# interval_search==0.5.2
# logging==0.5.1.2
# matplotlib==3.8.3
# nbmetalog==0.2.6
# numpy==1.23.5
# opytional==0.1.0
# pandas==1.5.2
# pytest==7.2.2
# scipy==1.10.1
# seaborn==0.13.2
# re==2.2.1
# comm==0.2.2
# psutil==7.0.0
# zmq==27.0.0
# json==2.0.9
# ipykernel==6.29.5

# %%
mpl.rcParams.update(
    {
        "figure.figsize": (6, 1),
    },
)

# %% [markdown]
# ## Animate Reservations

# %%
os.makedirs("30", exist_ok=True)
for surface_size in 8, 16, 32:
    surface_history_df = pylib.site_selection_eval.make_surface_history_df(
        hybrid_algo.pick_ingest_site,
        surface_size=surface_size,
        num_generations=min(2**(surface_size // 2 - 1) - 1, 256),
        progress_wrap=tqdm,
    ).replace(-1, np.nan)
    for writer, ext, kwargs in (
        (
            "ffmpeg",
            ".gif",
            {},
        ),
    ):
        anim = pylib.site_selection_viz.typewriter_animate(surface_history_df)
        filename =  f"30/viz=typewriter+surface_size={surface_size}+ext={ext}"
        anim.save(
            filename,
            fps=8,
            writer=writer,
            **kwargs,
        )
        print(f"saved {filename}")
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 21383.92it/s]
# /home/runner/work/hstrat-surface-concept/hstrat-surface-concept/binder/pylib/site_selection_viz/_apply_pseudo_linear_yticks.py:13: UserWarning: Precision is 0, aborting pseudo-linear y-axis labeling
#   warnings.warn("Precision is 0, aborting pseudo-linear y-axis labeling")
# saved 30/viz=typewriter+surface_size=8+ext=.gif
# 100%|██████████| 127/127 [00:00<00:00, 1259.83it/s]
# saved 30/viz=typewriter+surface_size=16+ext=.gif
# 100%|██████████| 256/256 [00:00<00:00, 35009.51it/s]
# saved 30/viz=typewriter+surface_size=32+ext=.gif

# %% [markdown]
# ## Visualize

# %%
for surface_size_exp in range(4, 9):
    surface_size = 2**surface_size_exp
    display(HTML(f"<h3>surface size {surface_size}</h3>"))

    # don't run out of memory
    num_generations = 2**18 if surface_size_exp < 7 else 2**12

    surface_history_df = pylib.site_selection_eval.make_surface_history_df(
        hybrid_algo.pick_ingest_site,
        surface_size=surface_size,
        num_generations=min(num_generations, hybrid_algo.get_ingest_capacity(surface_size)),
        progress_wrap=tqdm,
    )

    # ========================
    kwargs = dict(
        ynorm="log",
    )
    pylib.tee_release(
        pylib.site_selection_viz.site_differentia_by_rank_heatmap,
        surface_history_df,
        **kwargs,
        teeplot_outattrs={
            **{
                "num-generations": num_generations,
                "surface-size": surface_size,
            },
            **kwargs,
        },
        teeplot_subdir="30",
    )

    # ========================
    kwargs = dict(
        ynorm="linear",
    )
    pylib.tee_release(
        pylib.site_selection_viz.site_differentia_by_rank_heatmap,
        surface_history_df,
        **kwargs,
        teeplot_outattrs={
            **{
                "num-generations": num_generations,
                "surface-size": surface_size,
            },
            **kwargs,
        },
        teeplot_subdir="30",
    )

    # ========================
    kwargs = dict(
        cnorm="log",
        ynorm="log",
    )
    pylib.tee_release(
        pylib.site_selection_viz.site_ingest_rank_by_rank_heatmap,
        surface_history_df,
        **kwargs,
        teeplot_outattrs={
            **{
                "num-generations": num_generations,
                "surface-size": surface_size,
            },
            **kwargs,
        },
        teeplot_subdir="30",
    )

    # ========================
    kwargs = dict(
        cnorm=None,
        ynorm="linear",
    )
    pylib.tee_release(
        pylib.site_selection_viz.site_ingest_rank_by_rank_heatmap,
        surface_history_df,
        **kwargs,
        teeplot_outattrs={
            **{
                "num-generations": num_generations,
                "surface-size": surface_size,
            },
            **kwargs,
        },
        teeplot_subdir="30",
    )

    # ========================
    pylib.tee_release(
        pylib.site_selection_viz.site_hanoi_value_by_rank_heatmap,
        surface_history_df,
        teeplot_outattrs={
            "num-generations": num_generations,
            "surface-size": surface_size,
        },
        teeplot_subdir="30",
    )

    # ========================
    kwargs = dict(
        ynorm="linear",
    )
    pylib.tee_release(
        pylib.site_selection_viz.site_hanoi_value_by_rank_heatmap,
        surface_history_df,
        **kwargs,
        teeplot_outattrs={
            **{
                "num-generations": num_generations,
                "surface-size": surface_size,
            },
            **kwargs,
        },
        teeplot_subdir="30",
    )

    # ========================
    kwargs = dict(
        cnorm="log",
        ynorm="log",
    )
    pylib.tee_release(
        pylib.site_selection_viz.site_ingest_depth_by_rank_heatmap,
        surface_history_df,
        **kwargs,
        teeplot_outattrs={
            **{
                "num-generations": num_generations,
                "surface-size": surface_size,
            },
            **kwargs,
        },
        teeplot_subdir="30",
    )

    # ========================
    kwargs = dict(
        cnorm="log",
        ynorm="linear",
    )
    pylib.tee_release(
        pylib.site_selection_viz.site_ingest_depth_by_rank_heatmap,
        surface_history_df,
        **kwargs,
        teeplot_outattrs={
            **{
                "num-generations": num_generations,
                "surface-size": surface_size,
            },
            **kwargs,
        },
        teeplot_subdir="30",
    )

    # ========================
    pylib.tee_release(
        pylib.site_selection_viz.stratum_persistence_dripplot,
        surface_history_df[surface_history_df["rank"] < 3000],
        teeplot_outattrs={
            "num-generations": num_generations,
            "surface-size": surface_size,
        },
        teeplot_subdir="30",
        progress_wrap=tqdm,
    )
# Out:
# <h3>surface size 16</h3>
# 100%|██████████| 511/511 [00:00<00:00, 39818.11it/s]
# teeplots/30/num-generations=262144+surface-size=16+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=16+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/num-generations=262144+surface-size=16+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=16+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=262144+surface-size=16+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=262144+surface-size=16+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=None+num-generations=262144+surface-size=16+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=None+num-generations=262144+surface-size=16+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/num-generations=262144+surface-size=16+viz=site-hanoi-value-by-rank-heatmap+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=16+viz=site-hanoi-value-by-rank-heatmap+ext=.png
# teeplots/30/num-generations=262144+surface-size=16+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=16+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=262144+surface-size=16+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=262144+surface-size=16+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=log+num-generations=262144+surface-size=16+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=log+num-generations=262144+surface-size=16+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.png
# 100%|██████████| 509/509 [00:01<00:00, 363.18it/s]
# teeplots/30/num-generations=262144+surface-size=16+viz=stratum-persistence-dripplot+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=16+viz=stratum-persistence-dripplot+ext=.png
# <h3>surface size 32</h3>
# 100%|██████████| 131071/131071 [00:03<00:00, 36710.39it/s]
# teeplots/30/num-generations=262144+surface-size=32+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=32+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/num-generations=262144+surface-size=32+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=32+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=262144+surface-size=32+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=262144+surface-size=32+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=None+num-generations=262144+surface-size=32+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=None+num-generations=262144+surface-size=32+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/num-generations=262144+surface-size=32+viz=site-hanoi-value-by-rank-heatmap+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=32+viz=site-hanoi-value-by-rank-heatmap+ext=.png
# teeplots/30/num-generations=262144+surface-size=32+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=32+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=262144+surface-size=32+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=262144+surface-size=32+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=log+num-generations=262144+surface-size=32+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=log+num-generations=262144+surface-size=32+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.png
# 100%|██████████| 2998/2998 [00:08<00:00, 368.76it/s]
# teeplots/30/num-generations=262144+surface-size=32+viz=stratum-persistence-dripplot+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=32+viz=stratum-persistence-dripplot+ext=.png
# <h3>surface size 64</h3>
# 100%|██████████| 262144/262144 [00:10<00:00, 25228.48it/s]
# teeplots/30/num-generations=262144+surface-size=64+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=64+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/num-generations=262144+surface-size=64+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=64+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=262144+surface-size=64+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=262144+surface-size=64+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=None+num-generations=262144+surface-size=64+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=None+num-generations=262144+surface-size=64+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/num-generations=262144+surface-size=64+viz=site-hanoi-value-by-rank-heatmap+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=64+viz=site-hanoi-value-by-rank-heatmap+ext=.png
# teeplots/30/num-generations=262144+surface-size=64+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=64+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=262144+surface-size=64+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=262144+surface-size=64+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=log+num-generations=262144+surface-size=64+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=log+num-generations=262144+surface-size=64+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.png
# 100%|██████████| 2998/2998 [00:08<00:00, 343.78it/s]
# teeplots/30/num-generations=262144+surface-size=64+viz=stratum-persistence-dripplot+ext=.pdf
# teeplots/30/num-generations=262144+surface-size=64+viz=stratum-persistence-dripplot+ext=.png
# <h3>surface size 128</h3>
# 100%|██████████| 4096/4096 [00:00<00:00, 16207.15it/s]
# teeplots/30/num-generations=4096+surface-size=128+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=128+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/num-generations=4096+surface-size=128+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=128+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=4096+surface-size=128+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=4096+surface-size=128+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=None+num-generations=4096+surface-size=128+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=None+num-generations=4096+surface-size=128+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/num-generations=4096+surface-size=128+viz=site-hanoi-value-by-rank-heatmap+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=128+viz=site-hanoi-value-by-rank-heatmap+ext=.png
# teeplots/30/num-generations=4096+surface-size=128+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=128+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=4096+surface-size=128+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=4096+surface-size=128+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=log+num-generations=4096+surface-size=128+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=log+num-generations=4096+surface-size=128+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.png
# 100%|██████████| 2998/2998 [00:10<00:00, 298.52it/s]
# teeplots/30/num-generations=4096+surface-size=128+viz=stratum-persistence-dripplot+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=128+viz=stratum-persistence-dripplot+ext=.png
# <h3>surface size 256</h3>
# 100%|██████████| 4096/4096 [00:00<00:00, 9048.66it/s]
# teeplots/30/num-generations=4096+surface-size=256+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=256+viz=site-differentia-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/num-generations=4096+surface-size=256+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=256+viz=site-differentia-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=4096+surface-size=256+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=4096+surface-size=256+viz=site-ingest-rank-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=None+num-generations=4096+surface-size=256+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=None+num-generations=4096+surface-size=256+viz=site-ingest-rank-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/num-generations=4096+surface-size=256+viz=site-hanoi-value-by-rank-heatmap+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=256+viz=site-hanoi-value-by-rank-heatmap+ext=.png
# teeplots/30/num-generations=4096+surface-size=256+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=256+viz=site-hanoi-value-by-rank-heatmap+ynorm=linear+ext=.png
# teeplots/30/cnorm=log+num-generations=4096+surface-size=256+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.pdf
# teeplots/30/cnorm=log+num-generations=4096+surface-size=256+viz=site-ingest-depth-by-rank-heatmap+ynorm=log+ext=.png
# teeplots/30/cnorm=log+num-generations=4096+surface-size=256+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.pdf
# teeplots/30/cnorm=log+num-generations=4096+surface-size=256+viz=site-ingest-depth-by-rank-heatmap+ynorm=linear+ext=.png
# 100%|██████████| 2998/2998 [00:11<00:00, 268.20it/s]
# teeplots/30/num-generations=4096+surface-size=256+viz=stratum-persistence-dripplot+ext=.pdf
# teeplots/30/num-generations=4096+surface-size=256+viz=stratum-persistence-dripplot+ext=.png

# %%
surface_size = 32
num_generations = 300

surface_history_df = pylib.site_selection_eval.make_surface_history_df(
    hybrid_algo.pick_ingest_site,
    surface_size,
    num_generations,
    tqdm,
)


# ========================
def scatter_move_legend(*args, **kwargs) -> None:
    ax = sns.scatterplot(
        *args,
        **kwargs,
    )
    sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))


pylib.tee_release(
    scatter_move_legend,
    data=surface_history_df,
    x="rank",
    y="site",
    hue="ingest rank",
    teeplot_outattrs={
        "num-generations": num_generations,
        "surface-size": surface_size,
    },
    teeplot_subdir="30",
)


# ========================
def scatter_invert(*args, **kwargs) -> None:
    sns.scatterplot(
        *args,
        **kwargs,
    ).invert_yaxis()


pylib.tee_release(
    scatter_invert,
    data=surface_history_df,
    x="ingest rank",
    y="rank",
    hue="site",
    teeplot_outattrs={
        "num-generations": num_generations,
        "surface-size": surface_size,
    },
    teeplot_subdir="30",
)


# ========================
def scatter_invert_zoom(*args, **kwargs) -> None:
    ax = sns.scatterplot(
        *args,
        **kwargs,
    )
    ax.set_xlim([200, 250])
    ax.set_ylim([200, 250])
    ax.invert_yaxis()


pylib.tee_release(
    scatter_invert_zoom,
    data=surface_history_df,
    x="ingest rank",
    y="rank",
    hue="site",
    teeplot_outattrs={
        "num-generations": num_generations,
        "surface-size": surface_size,
    },
    teeplot_subdir="30",
)
# Out:
# 100%|██████████| 300/300 [00:00<00:00, 42918.73it/s]
# teeplots/30/hue=ingest-rank+num-generations=300+surface-size=32+viz=scatter-move-legend+x=rank+y=site+ext=.pdf
# teeplots/30/hue=ingest-rank+num-generations=300+surface-size=32+viz=scatter-move-legend+x=rank+y=site+ext=.png
# teeplots/30/hue=site+num-generations=300+surface-size=32+viz=scatter-invert+x=ingest-rank+y=rank+ext=.pdf
# teeplots/30/hue=site+num-generations=300+surface-size=32+viz=scatter-invert+x=ingest-rank+y=rank+ext=.png
# teeplots/30/hue=site+num-generations=300+surface-size=32+viz=scatter-invert-zoom+x=ingest-rank+y=rank+ext=.pdf
# teeplots/30/hue=site+num-generations=300+surface-size=32+viz=scatter-invert-zoom+x=ingest-rank+y=rank+ext=.png
